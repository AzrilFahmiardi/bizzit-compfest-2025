# %%
import pandas as pd

# %%
df = pd.read_csv('produk_data_updated.csv')

# %%
df = df.drop('expire_date', axis=1)

# %%
df
# Out:
#       id_produk kode_sku                         nama_produk kategori_produk  \
# 0      P0000001  SKU0009               Indomilk UHT Plain 1L            Susu
# 1      P0000002  SKU0499  Chitato Kentang Sapi Panggang 100g         Keripik
# 2      P0000003  SKU0542    Piattos Singkong Rumput Laut 60g         Keripik
# 3      P0000004  SKU0639          Indomie Kuah Kari Ayam 80g       Mi Instan
# 4      P0000005  SKU0061   Frisian Flag Bubuk Stroberi 200ml            Susu
# ...         ...      ...                                 ...             ...
# 89893  P0089894  SKU0039        Ultra Milk Bubuk Plain 200ml            Susu
# 89894  P0089895  SKU0207       Teh Botol Kemasan Lemon 500ml             Teh
# 89895  P0089896  SKU0365      Holland Bakery Tawar Keju 200g            Roti
# 89896  P0089897  SKU0427           Nabati Kaleng Kelapa 500g         Biskuit
# 89897  P0089898  SKU0726            So Good Nugget Sapi 500g     Frozen food
#
# ...

# %%
df.to_csv('produk_updated.csv', index=False)
